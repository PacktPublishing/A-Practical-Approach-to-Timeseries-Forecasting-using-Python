# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Import Dataset
df=pd.read_csv('BirthR.csv')

# %%
df.head()
# Out:
#        Date  births  year  month  date_of_month  day_of_week
# 0  1/1/1994    8096  1994      1              1            6
# 1  1/2/1994    7772  1994      1              2            7
# 2  1/3/1994   10142  1994      1              3            1
# 3  1/4/1994   11248  1994      1              4            2
# 4  1/5/1994   11053  1994      1              5            3

# %%
df.tail()
# Out:
#             Date  births  year  month  date_of_month  day_of_week
# 7665  12/27/2014    8656  2014     12             27            6
# 7666  12/28/2014    7724  2014     12             28            7
# 7667  12/29/2014   12811  2014     12             29            1
# 7668  12/30/2014   13634  2014     12             30            2
# 7669  12/31/2014   11990  2014     12             31            3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7670 entries, 0 to 7669
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           7670 non-null   object
#  1   births         7670 non-null   int64
#  2   year           7670 non-null   int64
#  3   month          7670 non-null   int64
#  4   date_of_month  7670 non-null   int64
#  5   day_of_week    7670 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 359.7+ KB

# %%
# birthrate according to year
#Bar plot (babies per year)
plt.figure(figsize=(18,5))
dist1=df.groupby("year")["births"].mean()
dist1.plot(kind='bar', rot=2)
plt.xlabel("Year", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Years Distribution", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,4))
year_sum=df.groupby("year")[['births']].sum()
plt.plot(year_sum,linewidth=3,color="r")
plt.xlabel("Year", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(range(1994,2015,1),fontsize=12)
plt.yticks(fontsize=12)
plt.title("Birth rate 1994-2014", fontsize=16,color="r")
plt.show()

# %%
#distribution of birth per month
#birth rate per month
plt.figure(figsize=(15,7))
dist1=df.groupby("month")["births"].mean()

dist1.plot(kind='bar', rot=0)
plt.xlabel("months",fontsize=12,color="r")
plt.ylabel("births", fontsize=12,color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("month's distribution", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,4))
mon_sum=df.groupby("month")[['births']].sum()
plt.plot(mon_sum,linewidth=3,color="r")
plt.xlabel("Year", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Birth rate per month 1994-2014", fontsize=16,color="r")
plt.show()

# %%
#distribution of birth per week days
#birth rate per week days

plt.figure(figsize=(15,7))
dist1=df.groupby("day_of_week")["births"].mean()

dist1.plot(kind='bar', rot=0)
plt.xlabel("day of week",fontsize=12,color="r")
plt.ylabel("births", fontsize=12,color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Weekday's distribution", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,4))
week_sum=df.groupby("day_of_week")[['births']].sum()
plt.plot(week_sum,linewidth=3,color="r")
plt.xlabel("Year", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Birth rate per week 1994-2014", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,7))
dist1=df.groupby("date_of_month")["births"].mean()

dist1.plot(kind='bar', rot=0)
plt.xlabel("day of month",fontsize=12,color="r")
plt.ylabel("births", fontsize=12,color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Month's distribution", fontsize=16,color="r")
plt.show()

# %%
plt.figure(figsize=(15,4))
Date_month_sum=df.groupby("date_of_month")[['births']].sum()
plt.plot(Date_month_sum,linewidth=3,color="r")
plt.xlabel("days of month", fontsize=14, color="r")
plt.ylabel("Births", fontsize=14, color="r")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Birth rate per day of month 1994-2014", fontsize=16,color="r")
plt.show()

# %%
#Range of birthrate per year

plt.figure(figsize=(18,5))
year_min=df.groupby("year")[['births']].min()
year_max=df.groupby("year")[['births']].max()
year_mean=df.groupby("year")[['births']].mean()
year_std=df.groupby("year")[['births']].std()

x=year_mean.index
plt.plot(year_max,linewidth=3,label="Max",color="b")
plt.plot(year_mean,linewidth=3,label="Average",color="g")
plt.plot(year_min,linewidth=3,label="Min",color="r")
plt.plot(year_std,linewidth=3,label="STD",color="k")

plt.fill_between(x,year_min["births"],year_max["births"],alpha=0.3, facecolor='yellow')
plt.xticks(range(1994,2015,1), fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel("Years", fontsize=12,color="r")
plt.ylabel("Value", fontsize=12,color="r")
plt.title("range of birth rate", fontsize=16,color="r")
plt.legend(loc='best')
plt.draw()

# %%
df.describe()
# Out:
#              births         year        month  date_of_month  day_of_week
# count   7670.000000  7670.000000  7670.000000    7670.000000  7670.000000
# mean   11132.493742  2004.000000     6.523077      15.729205     3.999870
# std     2172.398653     6.055444     3.448888       8.800483     2.000359
# min     5728.000000  1994.000000     1.000000       1.000000     1.000000
# 25%     8759.000000  1999.000000     4.000000       8.000000     2.000000
# 50%    11941.000000  2004.000000     7.000000      16.000000     4.000000
# 75%    12754.750000  2009.000000    10.000000      23.000000     6.000000
# max    16081.000000  2014.000000    12.000000      31.000000     7.000000

# %%
df.corr()
# Out:
#                  births          year         month  date_of_month  \
# births         1.000000  7.596776e-02  6.016844e-02  -3.189555e-03
# year           0.075968  1.000000e+00 -6.388353e-18  -1.168337e-17
# month          0.060168 -6.388353e-18  1.000000e+00   1.058747e-02
# date_of_month -0.003190 -1.168337e-17  1.058747e-02   1.000000e+00
# day_of_week   -0.674588 -3.444747e-04  1.043892e-04   7.206498e-05
#
#                day_of_week
# births           -0.674588
# year             -0.000344
# month             0.000104
# date_of_month     0.000072
# day_of_week       1.000000

# %%
df.shape
# Out:
# (7670, 6)

# %%
df.columns
# Out:
# Index(['Date', 'births', 'year', 'month', 'date_of_month', 'day_of_week'], dtype='object')

# %%
df.isnull().any()
# Out:
# Date             False
# births           False
# year             False
# month            False
# date_of_month    False
# day_of_week      False
# dtype: bool

# %%
#stationarity check
from statsmodels.tsa.stattools import adfuller

# %%
X= df.births.values
result=adfuller(X)
print('ADF Statistics:%f'%result[0])
print('p-value:%f'%result[1])
print('critical values')
for key,value in result[4].items():
    print('\t%s: %.3f'%(key,value))
# Out:
# ADF Statistics:-4.085969
# p-value:0.001022
# critical values
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
df['Date']
# Out:
# 0         1/1/1994
# 1         1/2/1994
# 2         1/3/1994
# 3         1/4/1994
# 4         1/5/1994
#            ...
# 7665    12/27/2014
# 7666    12/28/2014
# 7667    12/29/2014
# 7668    12/30/2014
# 7669    12/31/2014
# Name: Date, Length: 7670, dtype: object

# %%
train_dates=pd.to_datetime(df['Date'])
train_dates
# Out:
# 0      1994-01-01
# 1      1994-01-02
# 2      1994-01-03
# 3      1994-01-04
# 4      1994-01-05
#           ...
# 7665   2014-12-27
# 7666   2014-12-28
# 7667   2014-12-29
# 7668   2014-12-30
# 7669   2014-12-31
# Name: Date, Length: 7670, dtype: datetime64[ns]

# %%
cols= list(df)[1:2]
cols
# Out:
# ['births']

# %%
df_for_training=df[cols].astype(float)

# %%
df_for_training
# Out:
#        births
# 0      8096.0
# 1      7772.0
# 2     10142.0
# 3     11248.0
# 4     11053.0
# ...       ...
# 7665   8656.0
# 7666   7724.0
# 7667  12811.0
# 7668  13634.0
# 7669  11990.0
#
# [7670 rows x 1 columns]

# %%
df_for_plot=df_for_training
df_for_plot.plot.line(figsize=(18,8))

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaler=scaler.fit(df_for_training)
df_for_training_scaled=scaler.transform(df_for_training)

df_for_training_scaled
# Out:
# array([[-1.39785196],
#        [-1.54700558],
#        [-0.45597447],
#        ...,
#        [ 0.7727015 ],
#        [ 1.15157011],
#        [ 0.39475359]])

# %%
df_for_training.shape[1]
# Out:
# 1

# %%
trainX=[]
trainY=[]

n_future = 100
n_past = 20

for i in range(n_past, len(df_for_training_scaled) - n_future +1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])
    
trainX, trainY =np.array(trainX), np.array(trainY)

print('trainX shape==={}.'.format(trainX.shape))
print('trainY shape==={}.'.format(trainY.shape))
# Out:
# trainX shape===(7551, 20, 1).
# trainY shape===(7551, 1).

# %%
from keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional

# %%
model=Sequential()

# model.add(LSTM(32,activation='relu', input_shape=(trainX.shape[1],trainX.shape[2]),return_sequences=True))
model.add(Bidirectional(LSTM(32, return_sequences=True),input_shape=(trainX.shape[1],trainX.shape[2])))
model.add(Dropout(0.5))

model.add(Bidirectional(LSTM(32)))
model.add(Dropout(0.5))

model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (None, 20, 64)           8704
#  nal)
#
#  dropout_9 (Dropout)         (None, 20, 64)            0
#
#  bidirectional_5 (Bidirectio  (None, 64)               24832
#  nal)
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(trainX, trainY, epochs=100, batch_size=10, validation_split=0.1,verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000024E9F9916A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000024E9F9916A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 675/680 [============================>.] - ETA: 0s - loss: 0.3551WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000024EA0215EA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000024EA0215EA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 680/680 [==============================] - 14s 12ms/step - loss: 0.3535 - val_loss: 0.2713
# Epoch 2/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.2179 - val_loss: 0.2464
# Epoch 3/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.2068 - val_loss: 0.2098
# Epoch 4/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1983 - val_loss: 0.1957
# Epoch 5/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1941 - val_loss: 0.1981
# Epoch 6/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1920 - val_loss: 0.2046
# Epoch 7/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1841 - val_loss: 0.1973
# Epoch 8/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1830 - val_loss: 0.2093
# Epoch 9/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1751 - val_loss: 0.1986
# Epoch 10/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1742 - val_loss: 0.1808
# Epoch 11/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1679 - val_loss: 0.1718
# Epoch 12/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1665 - val_loss: 0.2108
# Epoch 13/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1639 - val_loss: 0.1990
# Epoch 14/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1646 - val_loss: 0.1804
# Epoch 15/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1648 - val_loss: 0.1820
# Epoch 16/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1646 - val_loss: 0.1936
# Epoch 17/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1602 - val_loss: 0.1741
# Epoch 18/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1587 - val_loss: 0.2066
# Epoch 19/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1578 - val_loss: 0.1850
# Epoch 20/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1595 - val_loss: 0.1825
# Epoch 21/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1571 - val_loss: 0.1928
# Epoch 22/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1581 - val_loss: 0.1760
# Epoch 23/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1589 - val_loss: 0.1997
# Epoch 24/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1538 - val_loss: 0.1834
# Epoch 25/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1535 - val_loss: 0.1890
# Epoch 26/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1541 - val_loss: 0.1856
# Epoch 27/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1536 - val_loss: 0.1870
# Epoch 28/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1548 - val_loss: 0.1785
# Epoch 29/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1530 - val_loss: 0.2061
# Epoch 30/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1521 - val_loss: 0.2009
# Epoch 31/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1521 - val_loss: 0.2143
# Epoch 32/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1525 - val_loss: 0.1846
# Epoch 33/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1506 - val_loss: 0.1951
# Epoch 34/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1538 - val_loss: 0.1845
# Epoch 35/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1504 - val_loss: 0.2081
# Epoch 36/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1504 - val_loss: 0.1973
# Epoch 37/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1480 - val_loss: 0.1647
# Epoch 38/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1520 - val_loss: 0.1980
# Epoch 39/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1492 - val_loss: 0.1875
# Epoch 40/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1481 - val_loss: 0.2134
# Epoch 41/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1483 - val_loss: 0.1774
# Epoch 42/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1484 - val_loss: 0.1771
# Epoch 43/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1468 - val_loss: 0.2051
# Epoch 44/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1458 - val_loss: 0.1763
# Epoch 45/100
# 680/680 [==============================] - 7s 10ms/step - loss: 0.1450 - val_loss: 0.1949
# Epoch 46/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1442 - val_loss: 0.1802
# Epoch 47/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1456 - val_loss: 0.1607
# Epoch 48/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1449 - val_loss: 0.1934
# Epoch 49/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1454 - val_loss: 0.1865
# Epoch 50/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1440 - val_loss: 0.1792
# Epoch 51/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1429 - val_loss: 0.1890
# Epoch 52/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1412 - val_loss: 0.1622
# Epoch 53/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1424 - val_loss: 0.1672
# Epoch 54/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1429 - val_loss: 0.2030
# Epoch 55/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1425 - val_loss: 0.1733
# Epoch 56/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1438 - val_loss: 0.2094
# Epoch 57/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1402 - val_loss: 0.1694
# Epoch 58/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1432 - val_loss: 0.1615
# Epoch 59/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1407 - val_loss: 0.1784
# Epoch 60/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1405 - val_loss: 0.1831
# Epoch 61/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1402 - val_loss: 0.1738
# Epoch 62/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1400 - val_loss: 0.1768
# Epoch 63/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1409 - val_loss: 0.1570
# Epoch 64/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1374 - val_loss: 0.1652
# Epoch 65/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1375 - val_loss: 0.1714
# Epoch 66/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1377 - val_loss: 0.1689
# Epoch 67/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1390 - val_loss: 0.1747
# Epoch 68/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1383 - val_loss: 0.1773
# Epoch 69/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1368 - val_loss: 0.1696
# Epoch 70/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1376 - val_loss: 0.1925
# Epoch 71/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1372 - val_loss: 0.1852
# Epoch 72/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1321 - val_loss: 0.2022
# Epoch 73/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1342 - val_loss: 0.1726
# Epoch 74/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1349 - val_loss: 0.1794
# Epoch 75/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1331 - val_loss: 0.1794
# Epoch 76/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1346 - val_loss: 0.1570
# Epoch 77/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1353 - val_loss: 0.2006
# Epoch 78/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1344 - val_loss: 0.1845
# Epoch 79/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1324 - val_loss: 0.1731
# Epoch 80/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1330 - val_loss: 0.1555
# Epoch 81/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1313 - val_loss: 0.1677
# Epoch 82/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1321 - val_loss: 0.1679
# Epoch 83/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1308 - val_loss: 0.1770
# Epoch 84/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1352 - val_loss: 0.1909
# Epoch 85/100
# 680/680 [==============================] - 9s 13ms/step - loss: 0.1314 - val_loss: 0.1555
# Epoch 86/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1300 - val_loss: 0.1697
# Epoch 87/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1341 - val_loss: 0.2000
# Epoch 88/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1311 - val_loss: 0.1777
# Epoch 89/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1286 - val_loss: 0.1851
# Epoch 90/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1330 - val_loss: 0.1789
# Epoch 91/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1289 - val_loss: 0.1762
# Epoch 92/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1339 - val_loss: 0.1771
# Epoch 93/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1277 - val_loss: 0.1681
# Epoch 94/100
# 680/680 [==============================] - 8s 12ms/step - loss: 0.1289 - val_loss: 0.1782
# Epoch 95/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1297 - val_loss: 0.1639
# Epoch 96/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1305 - val_loss: 0.1589
# Epoch 97/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1299 - val_loss: 0.1819
# Epoch 98/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1292 - val_loss: 0.1756
# Epoch 99/100
# 680/680 [==============================] - 7s 11ms/step - loss: 0.1281 - val_loss: 0.1679
# Epoch 100/100
# 680/680 [==============================] - 8s 11ms/step - loss: 0.1318 - val_loss: 0.1563

# %%
plt.plot(history.history['loss'],label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
us_bd = CustomBusinessDay(calendar=USFederalHolidayCalendar())

# %%
n_past = 10
n_days_for_prediction=100  

predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction, freq=us_bd).tolist()

# %%
prediction = model.predict(trainX[-n_days_for_prediction:])
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000024EFFD270D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000024EFFD270D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
prediction_copies = np.repeat(prediction, df_for_training.shape[1], axis=-1)
prediction_copies.shape
# Out:
# (100, 1)

# %%
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

# %%
forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i.date())
    
df_forecast = pd.DataFrame({'Date':np.array(forecast_dates), 'births':y_pred_future})
df_forecast['Date']=pd.to_datetime(df_forecast['Date'])

# %%
original = df[['Date', 'births']]
original['Date']=pd.to_datetime(original['Date'])
original = original.loc[original['Date'] >= '2013-12-12']
import seaborn as sns
sns.set(rc = {'figure.figsize':(15,8)})
sns.lineplot(original['Date'], original['births'])
sns.lineplot(df_forecast['Date'], df_forecast['births'])
